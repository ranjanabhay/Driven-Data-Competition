# %%
import pandas as pd
import numpy as np
import os
DATA_DIR = "/Users/abhayranjan/scripts/GA/predicting-poverty"

data_paths = {'A': {'train': os.path.join(DATA_DIR, 'A', 'A_hhold_train.csv'),
                    'test' : os.path.join(DATA_DIR, 'A', 'A_hhold_test.csv')},
              'B': {'train': os.path.join(DATA_DIR, 'B', 'B_hhold_train.csv'),
                    'test' : os.path.join(DATA_DIR, 'B', 'B_hhold_test.csv')},
              'C' :{'train': os.path.join(DATA_DIR, 'C', 'C_hhold_train.csv'),
                    'test' : os.path.join(DATA_DIR, 'C', 'C_hhold_test.csv')}}

# %%
a_train = pd.read_csv(data_paths['A']['train'],index_col='id')
a_test  = pd.read_csv(data_paths['A']['test'],index_col='id')
b_train = pd.read_csv(data_paths['B']['train'],index_col='id')
b_test  = pd.read_csv(data_paths['B']['test'],index_col='id')
c_train = pd.read_csv(data_paths['C']['train'],index_col='id')
c_test  = pd.read_csv(data_paths['C']['test'],index_col='id')

# %%
print(a_train.poor.value_counts())
print(b_train.poor.value_counts())
print(c_train.poor.value_counts())
# Out:
# False    4500
# True     3703
# Name: poor, dtype: int64
# False    3004
# True      251
# Name: poor, dtype: int64
# False    5496
# True      973
# Name: poor, dtype: int64

# %%
def standardize(df,numeric_only=True):
    numeric = df.select_dtypes(include=['int64','float64'])
    #print(type(numeric))
    #normalize the dataset by subtracting by mean and dividing by standard deviation
    df[numeric.columns] = (numeric - numeric.mean())/numeric.std()
    return df

def pre_process(df,enforce_cols=None):
    df = standardize(df)
    df = pd.get_dummies(df)
    if enforce_cols is not None:
        to_drop = np.setdiff1d(df.columns,enforce_cols)
        to_add = np.setdiff1d(enforce_cols,df.columns)
        df.drop(to_drop,axis=1,inplace=True)
        df = df.assign(**{c: 0 for c in to_add})
    df.fillna(0,inplace=True)
    return df

def treat_missing_data(df):
    numeric_data = df.select_dtypes(include=['int64','float64'])
    numeric_columns = numeric_data.columns
    for numfield in numeric_columns:
        df[numfield].fillna(0,inplace=True)
    nonnumeric_data = df.select_dtypes(include=['object'])
    nonnumeric_columns = nonnumeric_data.columns
    for nonnumfield in nonnumeric_columns:
        df[nonnumfield].fillna(value=df[nonnumfield].mode(),inplace=True)
    return df

# %%
from sklearn.utils import resample

a_train = treat_missing_data(a_train)
a_train = pre_process(a_train)
a_test = treat_missing_data(a_test)
a_test = pre_process(a_test,enforce_cols=a_train.columns)
print(a_train.shape)
print(a_test.shape)
print(len(a_train.columns.values))
print(len(a_test.columns.values))


# Process the training data for Country B
b_train = treat_missing_data(b_train)
b_train = pre_process(b_train)
b_minority = b_train[b_train.poor == True]
b_majority = b_train[b_train.poor == False]
#Upsample minority class
b_minority_upsampled = resample(b_minority,replace=True,n_samples=3004,random_state=123)
b_train = pd.concat([b_majority,b_minority_upsampled])
b_test = treat_missing_data(b_test)
b_test = pre_process(b_test,enforce_cols=b_train.columns)
print(b_train.shape)
print(b_test.shape)
print(len(b_train.columns.values))
print(len(b_test.columns.values))


# Process the training data for Country C
c_train = treat_missing_data(c_train)
c_train = pre_process(c_train)
c_minority = c_train[c_train.poor == True]
c_majority = c_train[c_train.poor == False]
#Upsample minority class
c_minority_upsampled = resample(c_minority,replace=True,n_samples=5496,random_state=123)
c_train = pd.concat([c_majority,c_minority_upsampled])
c_test = treat_missing_data(c_test)
c_test = pre_process(c_test,enforce_cols=c_train.columns)
print(c_train.shape)
print(c_test.shape)
print(len(c_train.columns.values))
print(len(c_test.columns.values))
# Out:
# (8203, 860)
# (4041, 860)
# 860
# 860
# (6008, 1433)
# (1604, 1433)
# 1433
# 1433
# (10992, 796)
# (3187, 796)
# 796
# 796

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split

# For A
#print(set(a_train.drop('poor',axis=1).columns.values) - set(a_test.drop('poor',axis=1).columns.values))
aX_train = a_train.drop('poor',axis=1)
ay_train = a_train['poor']
aX_train1,aX_test1,ay_train1,ay_test1 = train_test_split(aX_train,ay_train,test_size=0.25,random_state=243)
model = XGBClassifier()
model.fit(aX_train1,ay_train1)
a_test = a_test[aX_train.columns]
#ay_pred = model.predict_proba(aX_test1)
ay_pred1 = model.predict_proba(a_test)
print(type(ay_pred1))
print(ay_pred1.shape)
print(ay_pred1)

# For B
bX_train = b_train.drop('poor',axis=1)
by_train = b_train['poor']
bX_train1,bX_test1,by_train1,by_test1 = train_test_split(bX_train,by_train,test_size=0.25,random_state=243)
model = XGBClassifier()
model.fit(bX_train1,by_train1)
b_test = b_test[bX_train.columns]
#ay_pred = model.predict_proba(aX_test1)
by_pred1 = model.predict_proba(b_test)
print(type(by_pred1))
print(by_pred1.shape)
print(by_pred1)

# For C
cX_train = c_train.drop('poor',axis=1)
cy_train = c_train['poor']
cX_train1,cX_test1,cy_train1,cy_test1 = train_test_split(cX_train,cy_train,test_size=0.25,random_state=243)
model = XGBClassifier(n_estimators=200,max_depth=5)
model.fit(cX_train1,cy_train1)
c_test = c_test[cX_train.columns]
#ay_pred = model.predict_proba(aX_test1)
cy_pred1 = model.predict_proba(c_test)
print(type(cy_pred1))
print(cy_pred1.shape)
print(cy_pred1)
# Out:
# <class 'numpy.ndarray'>
# (4041, 2)
# [[ 0.134045    0.865955  ]
#  [ 0.99322724  0.00677275]
#  [ 0.24383765  0.75616235]
#  ...,
#  [ 0.06526494  0.93473506]
#  [ 0.89070171  0.1092983 ]
#  [ 0.14841592  0.85158408]]
# <class 'numpy.ndarray'>
# (1604, 2)
# [[ 0.89526951  0.10473049]
#  [ 0.72878712  0.27121288]
#  [ 0.9410373   0.05896272]
#  ...,
#  [ 0.84740418  0.15259582]
#  [ 0.73501045  0.26498955]
#  [ 0.70341682  0.29658321]]
# <class 'numpy.ndarray'>
# (3187, 2)
# [[  9.99794781e-01   2.05233577e-04]
#  [  9.99953508e-01   4.64758159e-05]
#  [  9.99988019e-01   1.19749948e-05]
#  ...,
#  [  9.99865890e-01   1.34134607e-04]
#  [  9.99972820e-01   2.71671106e-05]
#  [  9.99864042e-01   1.35939728e-04]]

# %%
# Saving the submission file.

def make_country_sub(preds,test_feat,country):
    country_codes=['A','B','C']
    #Getting poor probabilities
    country_sub = pd.DataFrame(data=preds,columns=['poor'],index=test_feat.index)
    #print(country_sub)
    # add the country code for joining later
    country_sub["country"] = country
    #print(country_sub)
    return country_sub[["country","poor"]]

# %%
# Convert preds to dataframe
a_sub = make_country_sub(ay_pred1[:,1],a_test,'A')
b_sub = make_country_sub(by_pred1[:,1],b_test,'B')
c_sub = make_country_sub(cy_pred1[:,1],c_test,'C')

submission = pd.concat([a_sub,b_sub,c_sub])
print(submission.head(n=5))
submission.to_csv('submission.csv')
# Out:
#       country      poor
# id
# 418         A  0.865955
# 41249       A  0.006773
# 16205       A  0.756162
# 97501       A  0.009254
# 67756       A  0.924030

# %%
#a_train.columns.values
for column_name in a_train.columns.values:
    x = column_name
    t = "a_train[a_train."+x+"==1].shape[0]"
    print(":",t)
# Out:
# : a_train[a_train.nEsgxvAq==1].shape[0]
# : a_train[a_train.OMtioXZZ==1].shape[0]
# : a_train[a_train.YFMZwKrU==1].shape[0]
# : a_train[a_train.poor==1].shape[0]
# : a_train[a_train.TiwRslOh==1].shape[0]
# : a_train[a_train.wBXbHZmp_DkQlr==1].shape[0]
# : a_train[a_train.wBXbHZmp_JhtDR==1].shape[0]
# : a_train[a_train.SlDKnCuu_GUusz==1].shape[0]
# : a_train[a_train.SlDKnCuu_alLXR==1].shape[0]
# : a_train[a_train.KAJOWiiw_BIZns==1].shape[0]
# : a_train[a_train.KAJOWiiw_TuovO==1].shape[0]
# : a_train[a_train.KAJOWiiw_rqUAG==1].shape[0]
# : a_train[a_train.DsKacCdL_QGgpH==1].shape[0]
# : a_train[a_train.DsKacCdL_ZYabk==1].shape[0]
# : a_train[a_train.rtPrBBPl_feupP==1].shape[0]
# : a_train[a_train.rtPrBBPl_uxuSS==1].shape[0]
# : a_train[a_train.tMJrvvut_PHMVg==1].shape[0]
# : a_train[a_train.tMJrvvut_VYpgU==1].shape[0]
# : a_train[a_train.jdetlNNF_NDTCU==1].shape[0]
# : a_train[a_train.jdetlNNF_PUBDZ==1].shape[0]
# : a_train[a_train.maLAYXwi_TcuXF==1].shape[0]
# : a_train[a_train.maLAYXwi_cLAGr==1].shape[0]
# : a_train[a_train.maLAYXwi_sehIp==1].shape[0]
# : a_train[a_train.vwpsXRGk_ARuYG==1].shape[0]
# : a_train[a_train.vwpsXRGk_AjMVN==1].shape[0]
# : a_train[a_train.vwpsXRGk_BidgV==1].shape[0]
# : a_train[a_train.vwpsXRGk_DBUky==1].shape[0]
# : a_train[a_train.vwpsXRGk_IDkCg==1].shape[0]
# : a_train[a_train.vwpsXRGk_IJnCs==1].shape[0]
# : a_train[a_train.vwpsXRGk_NdlDR==1].shape[0]
# : a_train[a_train.vwpsXRGk_QRKWz==1].shape[0]
# : a_train[a_train.vwpsXRGk_RpXJc==1].shape[0]
# : a_train[a_train.vwpsXRGk_SaVqO==1].shape[0]
# : a_train[a_train.vwpsXRGk_VJaVA==1].shape[0]
# : a_train[a_train.vwpsXRGk_XAmOF==1].shape[0]
# : a_train[a_train.vwpsXRGk_XHmQd==1].shape[0]
# : a_train[a_train.vwpsXRGk_ZCIYy==1].shape[0]
# : a_train[a_train.vwpsXRGk_ZlqSm==1].shape[0]
# : a_train[a_train.vwpsXRGk_bUhyU==1].shape[0]
# : a_train[a_train.vwpsXRGk_esAQH==1].shape[0]
# : a_train[a_train.vwpsXRGk_hmAUm==1].shape[0]
# : a_train[a_train.vwpsXRGk_lwCkE==1].shape[0]
# : a_train[a_train.vwpsXRGk_mIqzL==1].shape[0]
# : a_train[a_train.vwpsXRGk_puHHm==1].shape[0]
# : a_train[a_train.vwpsXRGk_qNABl==1].shape[0]
# : a_train[a_train.vwpsXRGk_qXvRS==1].shape[0]
# : a_train[a_train.vwpsXRGk_qcizG==1].shape[0]
# : a_train[a_train.vwpsXRGk_sPNOc==1].shape[0]
# : a_train[a_train.vwpsXRGk_shPwO==1].shape[0]
# : a_train[a_train.vwpsXRGk_tXtkv==1].shape[0]
# : a_train[a_train.vwpsXRGk_vVbnO==1].shape[0]
# : a_train[a_train.vwpsXRGk_xzgJe==1].shape[0]
# : a_train[a_train.vwpsXRGk_yKWYC==1].shape[0]
# : a_train[a_train.vwpsXRGk_yygvO==1].shape[0]
# : a_train[a_train.sArDRIyX_IVbQJ==1].shape[0]
# : a_train[a_train.sArDRIyX_MwLvg==1].shape[0]
# : a_train[a_train.goxNwvnG_HXAld==1].shape[0]
# : a_train[a_train.goxNwvnG_wSMgG==1].shape[0]
# : a_train[a_train.TYhoEiNm_WQHDZ==1].shape[0]
# : a_train[a_train.TYhoEiNm_sdlSU==1].shape[0]
# : a_train[a_train.bgfNZfcj_aSGQn==1].shape[0]
# : a_train[a_train.bgfNZfcj_yqxGT==1].shape[0]
# : a_train[a_train.sYIButva_iZuWM==1].shape[0]
# : a_train[a_train.sYIButva_nMLtq==1].shape[0]
# : a_train[a_train.VZtBaoXL_AtADK==1].shape[0]
# : a_train[a_train.VZtBaoXL_TXVyB==1].shape[0]
# : a_train[a_train.VZtBaoXL_usVYt==1].shape[0]
# : a_train[a_train.GUvFHPNA_JGQEQ==1].shape[0]
# : a_train[a_train.GUvFHPNA_Smcsc==1].shape[0]
# : a_train[a_train.zFkComtB_JETTQ==1].shape[0]
# : a_train[a_train.zFkComtB_RnjPp==1].shape[0]
# : a_train[a_train.zFkComtB_zlEqv==1].shape[0]
# : a_train[a_train.fxbqfEWb_UcpSR==1].shape[0]
# : a_train[a_train.fxbqfEWb_WobIQ==1].shape[0]
# : a_train[a_train.HDMHzGif_PSbhz==1].shape[0]
# : a_train[a_train.HDMHzGif_iTCRl==1].shape[0]
# : a_train[a_train.zzwlWZZC_CtanB==1].shape[0]
# : a_train[a_train.zzwlWZZC_Xtgis==1].shape[0]
# : a_train[a_train.nGTepfos_ltpcC==1].shape[0]
# : a_train[a_train.nGTepfos_nvuhC==1].shape[0]
# : a_train[a_train.DxLvCGgv_GEOXc==1].shape[0]
# : a_train[a_train.DxLvCGgv_VbCFp==1].shape[0]
# : a_train[a_train.CbABToOI_VeoCE==1].shape[0]
# : a_train[a_train.CbABToOI_oHRvd==1].shape[0]
# : a_train[a_train.CbABToOI_tIJga==1].shape[0]
# : a_train[a_train.qgMygRvX_Bdpcw==1].shape[0]
# : a_train[a_train.qgMygRvX_NLzKp==1].shape[0]
# : a_train[a_train.qgMygRvX_afxHM==1].shape[0]
# : a_train[a_train.qgMygRvX_ffsLD==1].shape[0]
# : a_train[a_train.qgMygRvX_fqfAt==1].shape[0]
# : a_train[a_train.qgMygRvX_hGXsD==1].shape[0]
# : a_train[a_train.qgMygRvX_mCgXS==1].shape[0]
# : a_train[a_train.qgMygRvX_pTCuA==1].shape[0]
# : a_train[a_train.qgMygRvX_vswDo==1].shape[0]
# : a_train[a_train.fhKiXuMY_XqDGz==1].shape[0]
# : a_train[a_train.fhKiXuMY_nJuqx==1].shape[0]
# : a_train[a_train.uSKnVaKV_HNHAn==1].shape[0]
# : a_train[a_train.uSKnVaKV_uPkpA==1].shape[0]
# : a_train[a_train.hESBInAl_ZZLWA==1].shape[0]
# : a_train[a_train.hESBInAl_qmAUD==1].shape[0]
# : a_train[a_train.hESBInAl_tLvyF==1].shape[0]
# : a_train[a_train.nzTeWUeM_AMonU==1].shape[0]
# : a_train[a_train.nzTeWUeM_oKdrT==1].shape[0]
# : a_train[a_train.nzTeWUeM_tWXrX==1].shape[0]
# : a_train[a_train.BbKZUYsB_VxayU==1].shape[0]
# : a_train[a_train.BbKZUYsB_cyHKs==1].shape[0]
# : a_train[a_train.UCnazcxd_GELir==1].shape[0]
# : a_train[a_train.UCnazcxd_GuzQO==1].shape[0]
# : a_train[a_train.hTraVEWP_SLlcX==1].shape[0]
# : a_train[a_train.hTraVEWP_ZkQxz==1].shape[0]
# : a_train[a_train.aCfsveTu_PSJTO==1].shape[0]
# : a_train[a_train.aCfsveTu_kgmhs==1].shape[0]
# : a_train[a_train.EfkPrfXa_HPKQV==1].shape[0]
# : a_train[a_train.EfkPrfXa_vdDgH==1].shape[0]
# : a_train[a_train.NrvxpdMQ_FExyX==1].shape[0]
# : a_train[a_train.NrvxpdMQ_sdZwV==1].shape[0]
# : a_train[a_train.FcekeISI_AsSEW==1].shape[0]
# : a_train[a_train.FcekeISI_FdmMx==1].shape[0]
# : a_train[a_train.FcekeISI_jkpcP==1].shape[0]
# : a_train[a_train.NmAVTtfA_buans==1].shape[0]
# : a_train[a_train.NmAVTtfA_srfRJ==1].shape[0]
# : a_train[a_train.YTdCRVJt_SDrXD==1].shape[0]
# : a_train[a_train.YTdCRVJt_dROpA==1].shape[0]
# : a_train[a_train.YTdCRVJt_qdnoF==1].shape[0]
# : a_train[a_train.QyBloWXZ_LKzoc==1].shape[0]
# : a_train[a_train.QyBloWXZ_WUJmr==1].shape[0]
# : a_train[a_train.NGOnRdqc_HxWwl==1].shape[0]
# : a_train[a_train.NGOnRdqc_aDHDh==1].shape[0]
# : a_train[a_train.HKMQJANN_ObBVP==1].shape[0]
# : a_train[a_train.HKMQJANN_asAMg==1].shape[0]
# : a_train[a_train.HKMQJANN_nqAId==1].shape[0]
# : a_train[a_train.ZRrposmO_ZMPHr==1].shape[0]
# : a_train[a_train.ZRrposmO_ywnPq==1].shape[0]
# : a_train[a_train.wakWLjkG_AtJzc==1].shape[0]
# : a_train[a_train.wakWLjkG_DBYFB==1].shape[0]
# : a_train[a_train.vmZttwFZ_hACfi==1].shape[0]
# : a_train[a_train.vmZttwFZ_sfcDZ==1].shape[0]
# : a_train[a_train.dkoIJCbY_YWmHv==1].shape[0]
# : a_train[a_train.dkoIJCbY_fdbOn==1].shape[0]
# : a_train[a_train.NrUWfvEq_BnEzq==1].shape[0]
# : a_train[a_train.NrUWfvEq_UFOVN==1].shape[0]
# : a_train[a_train.NrUWfvEq_hWZvm==1].shape[0]
# : a_train[a_train.WqhniYIc_ATBPa==1].shape[0]
# : a_train[a_train.WqhniYIc_IbIUY==1].shape[0]
# : a_train[a_train.yHbEDILT_YScDp==1].shape[0]
# : a_train[a_train.yHbEDILT_vfweT==1].shape[0]
# : a_train[a_train.EJgrQqET_KdnLw==1].shape[0]
# : a_train[a_train.EJgrQqET_wdCvs==1].shape[0]
# : a_train[a_train.nGMEgWyl_SokyU==1].shape[0]
# : a_train[a_train.nGMEgWyl_UKOES==1].shape[0]
# : a_train[a_train.IIEHQNUc_DXLhU==1].shape[0]
# : a_train[a_train.IIEHQNUc_uVrbm==1].shape[0]
# : a_train[a_train.HfKRIwMb_QFawF==1].shape[0]
# : a_train[a_train.HfKRIwMb_UdKcj==1].shape[0]
# : a_train[a_train.NRVuZwXK_AxwRL==1].shape[0]
# : a_train[a_train.NRVuZwXK_GqvRD==1].shape[0]
# : a_train[a_train.NRVuZwXK_Lgwgt==1].shape[0]
# : a_train[a_train.NRVuZwXK_gLHsu==1].shape[0]
# : a_train[a_train.NRVuZwXK_kiAJB==1].shape[0]
# : a_train[a_train.NRVuZwXK_mkOIj==1].shape[0]
# : a_train[a_train.NRVuZwXK_qOgkL==1].shape[0]
# : a_train[a_train.NRVuZwXK_rpEnA==1].shape[0]
# : a_train[a_train.NRVuZwXK_sbeOr==1].shape[0]
# : a_train[a_train.UCAmikjV_oRtiU==1].shape[0]
# : a_train[a_train.UCAmikjV_ycFDT==1].shape[0]
# : a_train[a_train.UGbBCHRE_CdOJh==1].shape[0]
# : a_train[a_train.UGbBCHRE_UbtLs==1].shape[0]
# : a_train[a_train.uJYGhXqG_GJSmz==1].shape[0]
# : a_train[a_train.uJYGhXqG_WQPIf==1].shape[0]
# : a_train[a_train.bxKGlBYX_FWMHx==1].shape[0]
# : a_train[a_train.bxKGlBYX_bDOph==1].shape[0]
# : a_train[a_train.nCzVgxgY_Bqyxs==1].shape[0]
# : a_train[a_train.nCzVgxgY_DkINd==1].shape[0]
# : a_train[a_train.ltcNxFzI_aaPgB==1].shape[0]
# : a_train[a_train.ltcNxFzI_eGKYm==1].shape[0]
# : a_train[a_train.ltcNxFzI_qfNQz==1].shape[0]
# : a_train[a_train.ltcNxFzI_xoMGF==1].shape[0]
# : a_train[a_train.WbEDLWBH_QKdak==1].shape[0]
# : a_train[a_train.WbEDLWBH_hNkZm==1].shape[0]
# : a_train[a_train.IBPMYJlv_KlXHR==1].shape[0]
# : a_train[a_train.IBPMYJlv_ZUFtA==1].shape[0]
# : a_train[a_train.MxOgekdE_Cttil==1].shape[0]
# : a_train[a_train.MxOgekdE_opKSl==1].shape[0]
# : a_train[a_train.ggNglVqE_nmBHL==1].shape[0]
# : a_train[a_train.ggNglVqE_vJxeZ==1].shape[0]
# : a_train[a_train.YDgWYWcJ_ESZVQ==1].shape[0]
# : a_train[a_train.YDgWYWcJ_HspDh==1].shape[0]
# : a_train[a_train.SqGRfEuW_KFwaq==1].shape[0]
# : a_train[a_train.SqGRfEuW_QiWxT==1].shape[0]
# : a_train[a_train.SqGRfEuW_jGNyr==1].shape[0]
# : a_train[a_train.WiwmbjGW_MLQXR==1].shape[0]
# : a_train[a_train.WiwmbjGW_iHtOk==1].shape[0]
# : a_train[a_train.WiwmbjGW_qmJHY==1].shape[0]
# : a_train[a_train.benRXROb_coAxL==1].shape[0]
# : a_train[a_train.benRXROb_jzcPS==1].shape[0]
# : a_train[a_train.cOSBrarW_okNWr==1].shape[0]
# : a_train[a_train.cOSBrarW_vLHhC==1].shape[0]
# : a_train[a_train.JwtIxvKg_WnTLO==1].shape[0]
# : a_train[a_train.JwtIxvKg_kaiUF==1].shape[0]
# : a_train[a_train.lRGpWehf_mwImW==1].shape[0]
# : a_train[a_train.lRGpWehf_twDig==1].shape[0]
# : a_train[a_train.dSALvhyd_mbAAs==1].shape[0]
# : a_train[a_train.dSALvhyd_mlKLM==1].shape[0]
# : a_train[a_train.gfmfEyjQ_QLhGp==1].shape[0]
# : a_train[a_train.gfmfEyjQ_gWYrF==1].shape[0]
# : a_train[a_train.gfmfEyjQ_rPlHB==1].shape[0]
# : a_train[a_train.WbxAxHul_FnIvn==1].shape[0]
# : a_train[a_train.WbxAxHul_aaNTa==1].shape[0]
# : a_train[a_train.FlBqizNL_CalgA==1].shape[0]
# : a_train[a_train.FlBqizNL_Zloxq==1].shape[0]
# : a_train[a_train.bEPKkJXP_JPmiP==1].shape[0]
# : a_train[a_train.bEPKkJXP_RJueq==1].shape[0]
# : a_train[a_train.KjkrfGLD_AfgYR==1].shape[0]
# : a_train[a_train.KjkrfGLD_GVYCk==1].shape[0]
# : a_train[a_train.KjkrfGLD_KfoTG==1].shape[0]
# : a_train[a_train.KjkrfGLD_Lsuai==1].shape[0]
# : a_train[a_train.KjkrfGLD_UhSVl==1].shape[0]
# : a_train[a_train.KjkrfGLD_ljBjd==1].shape[0]
# : a_train[a_train.KjkrfGLD_qzGkS==1].shape[0]
# : a_train[a_train.KjkrfGLD_tnDpM==1].shape[0]
# : a_train[a_train.JbjHTYUM_OsWDo==1].shape[0]
# : a_train[a_train.JbjHTYUM_YummV==1].shape[0]
# : a_train[a_train.JbjHTYUM_btzNc==1].shape[0]
# : a_train[a_train.HmDAlkAH_DOsnH==1].shape[0]
# : a_train[a_train.HmDAlkAH_XDRNN==1].shape[0]
# : a_train[a_train.HmDAlkAH_flaUT==1].shape[0]
# : a_train[a_train.cqUmYeAp_Hdfye==1].shape[0]
# : a_train[a_train.cqUmYeAp_IXFlv==1].shape[0]
# : a_train[a_train.cqUmYeAp_NdMeQ==1].shape[0]
# : a_train[a_train.cqUmYeAp_RZNMQ==1].shape[0]
# : a_train[a_train.cqUmYeAp_UgFtF==1].shape[0]
# : a_train[a_train.cqUmYeAp_VFAuL==1].shape[0]
# : a_train[a_train.sFWbFEso_UVHjq==1].shape[0]
# : a_train[a_train.sFWbFEso_rBNeu==1].shape[0]
# : a_train[a_train.fHUZugEd_AdsXN==1].shape[0]
# : a_train[a_train.fHUZugEd_CTJkE==1].shape[0]
# : a_train[a_train.tZKoAqgl_WgZWE==1].shape[0]
# : a_train[a_train.tZKoAqgl_ypOMV==1].shape[0]
# : a_train[a_train.TqrXZaOw_UVVLc==1].shape[0]
# : a_train[a_train.TqrXZaOw_ihCpA==1].shape[0]
# : a_train[a_train.galsfNtg_AUjeY==1].shape[0]
# : a_train[a_train.galsfNtg_mizNl==1].shape[0]
# : a_train[a_train.VIRwrkXp_DYJcq==1].shape[0]
# : a_train[a_train.VIRwrkXp_TUHSx==1].shape[0]
# : a_train[a_train.dsIjcEFe_TgJJO==1].shape[0]
# : a_train[a_train.dsIjcEFe_oRMnJ==1].shape[0]
# : a_train[a_train.OybQOufM_efFyt==1].shape[0]
# : a_train[a_train.OybQOufM_gaKub==1].shape[0]
# : a_train[a_train.ihGjxdDj_cuIZH==1].shape[0]
# : a_train[a_train.ihGjxdDj_dWjOX==1].shape[0]
# : a_train[a_train.gwhBRami_SrVwP==1].shape[0]
# : a_train[a_train.gwhBRami_txrXc==1].shape[0]
# : a_train[a_train.FGYOIJbC_QDLBV==1].shape[0]
# : a_train[a_train.FGYOIJbC_snqZf==1].shape[0]
# : a_train[a_train.bPOwgKnT_DnomH==1].shape[0]
# : a_train[a_train.bPOwgKnT_THHLT==1].shape[0]
# : a_train[a_train.bPOwgKnT_WXYiE==1].shape[0]
# : a_train[a_train.bPOwgKnT_hMHca==1].shape[0]
# : a_train[a_train.bPOwgKnT_mDadf==1].shape[0]
# : a_train[a_train.bPOwgKnT_zPfZR==1].shape[0]
# : a_train[a_train.lybuQXPm_bTham==1].shape[0]
# : a_train[a_train.lybuQXPm_kvCsp==1].shape[0]
# : a_train[a_train.UBanubTh_NfQSU==1].shape[0]
# : a_train[a_train.UBanubTh_PKIOC==1].shape[0]
# : a_train[a_train.UBanubTh_vlSxF==1].shape[0]
# : a_train[a_train.JeydMEpC_TGEpP==1].shape[0]
# : a_train[a_train.JeydMEpC_ufskM==1].shape[0]
# : a_train[a_train.fpHOwfAs_JueeR==1].shape[0]
# : a_train[a_train.fpHOwfAs_zZmVq==1].shape[0]
# : a_train[a_train.VXXLUaXP_AtMKj==1].shape[0]
# : a_train[a_train.VXXLUaXP_qfRrQ==1].shape[0]
# : a_train[a_train.btgWptTG_KYiZb==1].shape[0]
# : a_train[a_train.btgWptTG_zVFte==1].shape[0]
# : a_train[a_train.NIRMacrk_mjTMV==1].shape[0]
# : a_train[a_train.NIRMacrk_rdvxf==1].shape[0]
# : a_train[a_train.YWwNfVtR_WONMC==1].shape[0]
# : a_train[a_train.YWwNfVtR_XOlpR==1].shape[0]
# : a_train[a_train.wxDnGIwN_XrqGT==1].shape[0]
# : a_train[a_train.wxDnGIwN_eUtuh==1].shape[0]
# : a_train[a_train.rAkSnhJF_DtMvg==1].shape[0]
# : a_train[a_train.rAkSnhJF_TKfyw==1].shape[0]
# : a_train[a_train.rAkSnhJF_qTmDg==1].shape[0]
# : a_train[a_train.rAkSnhJF_rXCdD==1].shape[0]
# : a_train[a_train.rAkSnhJF_zeYAm==1].shape[0]
# : a_train[a_train.EMDSHIlJ_dOgle==1].shape[0]
# : a_train[a_train.EMDSHIlJ_gmcLS==1].shape[0]
# : a_train[a_train.bgoWYRMQ_wKWZx==1].shape[0]
# : a_train[a_train.bgoWYRMQ_wpOnp==1].shape[0]
# : a_train[a_train.glEjrMIg_OcHBc==1].shape[0]
# : a_train[a_train.glEjrMIg_bkswa==1].shape[0]
# : a_train[a_train.bMudmjzJ_mOETh==1].shape[0]
# : a_train[a_train.bMudmjzJ_uTgod==1].shape[0]
# : a_train[a_train.GKUhYLAE_DDOFi==1].shape[0]
# : a_train[a_train.GKUhYLAE_fVvMw==1].shape[0]
# : a_train[a_train.GKUhYLAE_xOoQP==1].shape[0]
# : a_train[a_train.OnTaJkLa_LDyDX==1].shape[0]
# : a_train[a_train.OnTaJkLa_sbxXu==1].shape[0]
# : a_train[a_train.SsZAZLma_Hltat==1].shape[0]
# : a_train[a_train.SsZAZLma_fSMSz==1].shape[0]
# : a_train[a_train.BMmgMRvd_IjEdt==1].shape[0]
# : a_train[a_train.BMmgMRvd_QZujc==1].shape[0]
# : a_train[a_train.bIBQTaHw_ALZyK==1].shape[0]
# : a_train[a_train.bIBQTaHw_qqkkL==1].shape[0]
# : a_train[a_train.bIBQTaHw_wQABW==1].shape[0]
# : a_train[a_train.KcArMKAe_EbwxU==1].shape[0]
# : a_train[a_train.KcArMKAe_VFlsG==1].shape[0]
# : a_train[a_train.ofhkZaYa_CUTFq==1].shape[0]
# : a_train[a_train.ofhkZaYa_ioccr==1].shape[0]
# : a_train[a_train.VtcDnwsf_ujSKY==1].shape[0]
# : a_train[a_train.VtcDnwsf_vWcDA==1].shape[0]
# : a_train[a_train.TFrimNtw_GttxB==1].shape[0]
# : a_train[a_train.TFrimNtw_UVunH==1].shape[0]
# : a_train[a_train.enTUTSQi_eTMbs==1].shape[0]
# : a_train[a_train.enTUTSQi_wRJec==1].shape[0]
# : a_train[a_train.LjvKYNON_ZHiRw==1].shape[0]
# : a_train[a_train.LjvKYNON_fhqPC==1].shape[0]
# : a_train[a_train.LjvKYNON_prLFI==1].shape[0]
# : a_train[a_train.LjvKYNON_qQWKw==1].shape[0]
# : a_train[a_train.LjvKYNON_tFrTi==1].shape[0]
# : a_train[a_train.LjvKYNON_yVlbR==1].shape[0]
# : a_train[a_train.wwfmpuWA_SranW==1].shape[0]
# : a_train[a_train.wwfmpuWA_obtnu==1].shape[0]
# : a_train[a_train.znHDEHZP_OCLak==1].shape[0]
# : a_train[a_train.znHDEHZP_uDkol==1].shape[0]
# : a_train[a_train.kWFVfHWP_InbSQ==1].shape[0]
# : a_train[a_train.kWFVfHWP_ddRKR==1].shape[0]
# : a_train[a_train.XwVALSPR_ncoFd==1].shape[0]
# : a_train[a_train.XwVALSPR_vtHBY==1].shape[0]
# : a_train[a_train.TvShZEBA_ozBug==1].shape[0]
# : a_train[a_train.TvShZEBA_xsqtn==1].shape[0]
# : a_train[a_train.nuwxPLMe_EyaLN==1].shape[0]
# : a_train[a_train.nuwxPLMe_ZQDXs==1].shape[0]
# : a_train[a_train.eeYoszDM_RQQsQ==1].shape[0]
# : a_train[a_train.eeYoszDM_hHXMH==1].shape[0]
# : a_train[a_train.HHAeIHna_ExDLJ==1].shape[0]
# : a_train[a_train.HHAeIHna_ZhGcs==1].shape[0]
# : a_train[a_train.HHAeIHna_llGfE==1].shape[0]
# : a_train[a_train.CrfscGZl_ccdEk==1].shape[0]
# : a_train[a_train.CrfscGZl_xtqoI==1].shape[0]
# : a_train[a_train.dCGNTMiG_ENNVU==1].shape[0]
# : a_train[a_train.dCGNTMiG_SPzuq==1].shape[0]
# : a_train[a_train.ngwuvaCV_auPiK==1].shape[0]
# : a_train[a_train.ngwuvaCV_twMTS==1].shape[0]
# : a_train[a_train.yeHQSlwg_BELAV==1].shape[0]
# : a_train[a_train.yeHQSlwg_CtlxI==1].shape[0]
# : a_train[a_train.yeHQSlwg_JqHcg==1].shape[0]
# : a_train[a_train.yeHQSlwg_LiSdw==1].shape[0]
# : a_train[a_train.yeHQSlwg_OrmPF==1].shape[0]
# : a_train[a_train.yeHQSlwg_QjxqO==1].shape[0]
# : a_train[a_train.yeHQSlwg_RitVm==1].shape[0]
# : a_train[a_train.yeHQSlwg_dujst==1].shape[0]
# : a_train[a_train.yeHQSlwg_oQxCJ==1].shape[0]
# : a_train[a_train.XSgHIFXD_OUJop==1].shape[0]
# : a_train[a_train.XSgHIFXD_WkiLJ==1].shape[0]
# : a_train[a_train.GnUDarun_STusI==1].shape[0]
# : a_train[a_train.GnUDarun_lNXOe==1].shape[0]
# : a_train[a_train.iwkvfFnL_easnk==1].shape[0]
# : a_train[a_train.iwkvfFnL_iwXUz==1].shape[0]
# : a_train[a_train.ANBCxZzU_AQdXQ==1].shape[0]
# : a_train[a_train.ANBCxZzU_PpSAr==1].shape[0]
# : a_train[a_train.NanLCXEI_VQqYa==1].shape[0]
# : a_train[a_train.NanLCXEI_yOWNA==1].shape[0]
# : a_train[a_train.SqEqFZsM_SsMkV==1].shape[0]
# : a_train[a_train.SqEqFZsM_sYYqT==1].shape[0]
# : a_train[a_train.ZnBLVaqz_GRlEi==1].shape[0]
# : a_train[a_train.ZnBLVaqz_XZCPn==1].shape[0]
# : a_train[a_train.lQQeVmCa_njLjB==1].shape[0]
# : a_train[a_train.lQQeVmCa_rDnbh==1].shape[0]
# : a_train[a_train.lFcfBRGd_ODGAT==1].shape[0]
# : a_train[a_train.lFcfBRGd_USODW==1].shape[0]
# : a_train[a_train.MOIscfCf_CiTCp==1].shape[0]
# : a_train[a_train.MOIscfCf_rKIUz==1].shape[0]
# : a_train[a_train.AsEmHUzj_DCAbS==1].shape[0]
# : a_train[a_train.AsEmHUzj_GTHec==1].shape[0]
# : a_train[a_train.AsEmHUzj_IRaac==1].shape[0]
# : a_train[a_train.AsEmHUzj_MrnuQ==1].shape[0]
# : a_train[a_train.AsEmHUzj_Oqaht==1].shape[0]
# : a_train[a_train.AsEmHUzj_hwUPn==1].shape[0]
# : a_train[a_train.AsEmHUzj_tTlgE==1].shape[0]
# : a_train[a_train.AsEmHUzj_usGeg==1].shape[0]
# : a_train[a_train.YXkrVgqt_VrfVc==1].shape[0]
# : a_train[a_train.YXkrVgqt_daBsX==1].shape[0]
# : a_train[a_train.YXkrVgqt_qxEvp==1].shape[0]
# : a_train[a_train.pyBSpOoN_VMvrK==1].shape[0]
# : a_train[a_train.pyBSpOoN_lPYYk==1].shape[0]
# : a_train[a_train.srPNUgVy_JeaWK==1].shape[0]
# : a_train[a_train.srPNUgVy_pkIrP==1].shape[0]
# : a_train[a_train.srPNUgVy_xmRLH==1].shape[0]
# : a_train[a_train.UXSJUVwD_BQRJQ==1].shape[0]
# : a_train[a_train.UXSJUVwD_FJYAk==1].shape[0]
# : a_train[a_train.UXSJUVwD_IHJnm==1].shape[0]
# : a_train[a_train.UXSJUVwD_VtTSc==1].shape[0]
# : a_train[a_train.UXSJUVwD_dDaSf==1].shape[0]
# : a_train[a_train.UXSJUVwD_klEQr==1].shape[0]
# : a_train[a_train.UXSJUVwD_sbwIo==1].shape[0]
# : a_train[a_train.pCgBHqsR_iVlle==1].shape[0]
# : a_train[a_train.pCgBHqsR_uMicD==1].shape[0]
# : a_train[a_train.wEbmsuJO_MKsqC==1].shape[0]
# : a_train[a_train.wEbmsuJO_lkvLr==1].shape[0]
# : a_train[a_train.TWXCrjor_IrGtT==1].shape[0]
# : a_train[a_train.TWXCrjor_hwivA==1].shape[0]
# : a_train[a_train.TWXCrjor_jcWFw==1].shape[0]
# : a_train[a_train.wgWdGBOp_ZLoQH==1].shape[0]
# : a_train[a_train.wgWdGBOp_iZVhn==1].shape[0]
# : a_train[a_train.mRgnuJVE_KkIYu==1].shape[0]
# : a_train[a_train.mRgnuJVE_vnMwY==1].shape[0]
# : a_train[a_train.mRgnuJVE_xFGRe==1].shape[0]
# : a_train[a_train.pWyRKfsb_nQjzQ==1].shape[0]
# : a_train[a_train.pWyRKfsb_ziMON==1].shape[0]
# : a_train[a_train.udzhtHIr_BZdVV==1].shape[0]
# : a_train[a_train.udzhtHIr_EFEdw==1].shape[0]
# : a_train[a_train.ErggjCIN_BjHPw==1].shape[0]
# : a_train[a_train.ErggjCIN_qyiux==1].shape[0]
# : a_train[a_train.iVscWZyL_XdgGs==1].shape[0]
# : a_train[a_train.iVscWZyL_ziwzG==1].shape[0]
# : a_train[a_train.IZFarbPw_Bgigt==1].shape[0]
# : a_train[a_train.IZFarbPw_YNtzq==1].shape[0]
# : a_train[a_train.lnfulcWk_HodtS==1].shape[0]
# : a_train[a_train.lnfulcWk_JrCtE==1].shape[0]
# : a_train[a_train.UHGnBrNt_Ovzte==1].shape[0]
# : a_train[a_train.UHGnBrNt_YGDQb==1].shape[0]
# : a_train[a_train.UHGnBrNt_ysuMQ==1].shape[0]
# : a_train[a_train.QNLOXNwj_bAsHK==1].shape[0]
# : a_train[a_train.QNLOXNwj_wJZZG==1].shape[0]
# : a_train[a_train.ytYMzOlW_RAher==1].shape[0]
# : a_train[a_train.ytYMzOlW_usARW==1].shape[0]
# : a_train[a_train.RJQbcmKy_MGeNc==1].shape[0]
# : a_train[a_train.RJQbcmKy_eaOHN==1].shape[0]
# : a_train[a_train.uizuNzbk_faIKi==1].shape[0]
# : a_train[a_train.uizuNzbk_lePWK==1].shape[0]
# : a_train[a_train.dlyiMEQt_kLAQg==1].shape[0]
# : a_train[a_train.dlyiMEQt_sTELG==1].shape[0]
# : a_train[a_train.ucXrHdoC_CouUl==1].shape[0]
# : a_train[a_train.ucXrHdoC_OCxeM==1].shape[0]
# : a_train[a_train.ucXrHdoC_gUrMw==1].shape[0]
# : a_train[a_train.iBQXwnGC_TCThD==1].shape[0]
# : a_train[a_train.iBQXwnGC_hKOOZ==1].shape[0]
# : a_train[a_train.TnWhKowI_SyDCL==1].shape[0]
# : a_train[a_train.TnWhKowI_umQWl==1].shape[0]
# : a_train[a_train.sslNoPlw_HBAfC==1].shape[0]
# : a_train[a_train.sslNoPlw_vHsxI==1].shape[0]
# : a_train[a_train.InULRrrv_mCLIw==1].shape[0]
# : a_train[a_train.InULRrrv_pxTwJ==1].shape[0]
# : a_train[a_train.LoYIbglA_bNXgS==1].shape[0]
# : a_train[a_train.LoYIbglA_zJUXM==1].shape[0]
# : a_train[a_train.GhJKwVWC_BZDbR==1].shape[0]
# : a_train[a_train.GhJKwVWC_RBSxg==1].shape[0]
# : a_train[a_train.zXPyHBkn_pTmLW==1].shape[0]
# : a_train[a_train.zXPyHBkn_vHHYC==1].shape[0]
# : a_train[a_train.lVHmBCmb_pljjF==1].shape[0]
# : a_train[a_train.lVHmBCmb_vmKoA==1].shape[0]
# : a_train[a_train.EuJrVjyG_bleFi==1].shape[0]
# : a_train[a_train.EuJrVjyG_uaNFE==1].shape[0]
# : a_train[a_train.nSzbETYS_AhXJy==1].shape[0]
# : a_train[a_train.nSzbETYS_rUxTt==1].shape[0]
# : a_train[a_train.nSzbETYS_yTPHV==1].shape[0]
# : a_train[a_train.CpqWSQcW_GHLFz==1].shape[0]
# : a_train[a_train.CpqWSQcW_Nemmo==1].shape[0]
# : a_train[a_train.jxSUvflR_KmUXh==1].shape[0]
# : a_train[a_train.jxSUvflR_uSmDB==1].shape[0]
# : a_train[a_train.XqURHMoh_UWgUE==1].shape[0]
# : a_train[a_train.XqURHMoh_WDkZe==1].shape[0]
# : a_train[a_train.eoNxXdlZ_EDTNy==1].shape[0]
# : a_train[a_train.eoNxXdlZ_jXJpO==1].shape[0]
# : a_train[a_train.qgxmqJKa_CxUFg==1].shape[0]
# : a_train[a_train.qgxmqJKa_lPMcV==1].shape[0]
# : a_train[a_train.mDTcQhdH_CnUIQ==1].shape[0]
# : a_train[a_train.mDTcQhdH_tSlww==1].shape[0]
# : a_train[a_train.gfurxECf_OwpgR==1].shape[0]
# : a_train[a_train.gfurxECf_hUnoy==1].shape[0]
# : a_train[a_train.RLKqBexO_BSkcT==1].shape[0]
# : a_train[a_train.RLKqBexO_IxhgC==1].shape[0]
# : a_train[a_train.mvGdZZcs_EfseL==1].shape[0]
# : a_train[a_train.mvGdZZcs_NKTNl==1].shape[0]
# : a_train[a_train.mvGdZZcs_dIDIn==1].shape[0]
# : a_train[a_train.duayPuvk_BRnni==1].shape[0]
# : a_train[a_train.duayPuvk_UsIbc==1].shape[0]
# : a_train[a_train.hnrnuMte_FmBLH==1].shape[0]
# : a_train[a_train.hnrnuMte_McphZ==1].shape[0]
# : a_train[a_train.CbzSWtkF_bIVzQ==1].shape[0]
# : a_train[a_train.CbzSWtkF_fOYQs==1].shape[0]
# : a_train[a_train.LrQXqVUj_AlOmz==1].shape[0]
# : a_train[a_train.LrQXqVUj_JUIeR==1].shape[0]
# : a_train[a_train.XDDOZFWf_HfxcF==1].shape[0]
# : a_train[a_train.XDDOZFWf_qQocg==1].shape[0]
# : a_train[a_train.CIGUXrRQ_YBnSQ==1].shape[0]
# : a_train[a_train.CIGUXrRQ_gFTzO==1].shape[0]
# : a_train[a_train.ccAHraiP_FAceq==1].shape[0]
# : a_train[a_train.ccAHraiP_ycFFK==1].shape[0]
# : a_train[a_train.QayGNSmS_QaUlf==1].shape[0]
# : a_train[a_train.QayGNSmS_zQUnD==1].shape[0]
# : a_train[a_train.CtFxPQPT_atYJj==1].shape[0]
# : a_train[a_train.CtFxPQPT_vSqQC==1].shape[0]
# : a_train[a_train.ePtrWTFd_pyvgk==1].shape[0]
# : a_train[a_train.ePtrWTFd_vZiEt==1].shape[0]
# : a_train[a_train.tbsBPHFD_BdSqi==1].shape[0]
# : a_train[a_train.tbsBPHFD_qxdnm==1].shape[0]
# : a_train[a_train.naDKOzdk_AakrE==1].shape[0]
# : a_train[a_train.naDKOzdk_nkDDJ==1].shape[0]
# : a_train[a_train.lTAXSTys_EzaJv==1].shape[0]
# : a_train[a_train.lTAXSTys_luwoR==1].shape[0]
# : a_train[a_train.DNAfxPzs_gVjDv==1].shape[0]
# : a_train[a_train.DNAfxPzs_toKrg==1].shape[0]
# : a_train[a_train.GYTJWlaF_KNFyN==1].shape[0]
# : a_train[a_train.GYTJWlaF_tuhCX==1].shape[0]
# : a_train[a_train.xkUFKUoW_NyloK==1].shape[0]
# : a_train[a_train.xkUFKUoW_lKjvc==1].shape[0]
# : a_train[a_train.QzqNzAJE_aFKPY==1].shape[0]
# : a_train[a_train.QzqNzAJE_cDtZG==1].shape[0]
# : a_train[a_train.dEpQghsA_LDfpY==1].shape[0]
# : a_train[a_train.dEpQghsA_OUnra==1].shape[0]
# : a_train[a_train.jVDpuAmP_nkwue==1].shape[0]
# : a_train[a_train.jVDpuAmP_sqtPf==1].shape[0]
# : a_train[a_train.mnIQKNOM_VxMyV==1].shape[0]
# : a_train[a_train.mnIQKNOM_iNJOu==1].shape[0]
# : a_train[a_train.bhFgAObo_GMXrx==1].shape[0]
# : a_train[a_train.bhFgAObo_bfxJR==1].shape[0]
# : a_train[a_train.SeZULMCT_HRpuZ==1].shape[0]
# : a_train[a_train.SeZULMCT_IkIWR==1].shape[0]
# : a_train[a_train.AtGRGAYi_TpPTi==1].shape[0]
# : a_train[a_train.AtGRGAYi_XNUiY==1].shape[0]
# : a_train[a_train.AtGRGAYi_rwjPU==1].shape[0]
# : a_train[a_train.NitzgUzY_HGYnr==1].shape[0]
# : a_train[a_train.NitzgUzY_rwsVh==1].shape[0]
# : a_train[a_train.YlZCqMNw_EyXxl==1].shape[0]
# : a_train[a_train.YlZCqMNw_IIoXE==1].shape[0]
# : a_train[a_train.YlZCqMNw_UPXKK==1].shape[0]
# : a_train[a_train.FGDcbVBN_EBImk==1].shape[0]
# : a_train[a_train.FGDcbVBN_LzdSI==1].shape[0]
# : a_train[a_train.rYvVKPAF_CkZDJ==1].shape[0]
# : a_train[a_train.rYvVKPAF_OnSaH==1].shape[0]
# : a_train[a_train.WTFJilSZ_bOZlo==1].shape[0]
# : a_train[a_train.WTFJilSZ_jznhi==1].shape[0]
# : a_train[a_train.NBfffJUe_IBdTc==1].shape[0]
# : a_train[a_train.NBfffJUe_YKjEy==1].shape[0]
# : a_train[a_train.wnESwOiN_QfQGE==1].shape[0]
# : a_train[a_train.wnESwOiN_uZJuw==1].shape[0]
# : a_train[a_train.wnESwOiN_zdYLD==1].shape[0]
# : a_train[a_train.rfDBJtIz_QoQeZ==1].shape[0]
# : a_train[a_train.rfDBJtIz_UnNNe==1].shape[0]
# : a_train[a_train.rfDBJtIz_ZVfEw==1].shape[0]
# : a_train[a_train.mvgxfsRb_AXgBD==1].shape[0]
# : a_train[a_train.mvgxfsRb_QyySG==1].shape[0]
# : a_train[a_train.BwkgSxCk_JHrHU==1].shape[0]
# : a_train[a_train.BwkgSxCk_kHVqC==1].shape[0]
# : a_train[a_train.KHzKOKPw_MRwGf==1].shape[0]
# : a_train[a_train.KHzKOKPw_lhohM==1].shape[0]
# : a_train[a_train.UXfyiodk_HhERQ==1].shape[0]
# : a_train[a_train.UXfyiodk_MvlHX==1].shape[0]
# : a_train[a_train.EftwspgZ_dxbrH==1].shape[0]
# : a_train[a_train.EftwspgZ_hIvXl==1].shape[0]
# : a_train[a_train.EftwspgZ_lEsZp==1].shape[0]
# : a_train[a_train.pQmBvlkz_HlFcn==1].shape[0]
# : a_train[a_train.pQmBvlkz_zhfzx==1].shape[0]
# : a_train[a_train.mycoyYwl_kpQGr==1].shape[0]
# : a_train[a_train.mycoyYwl_ypBwu==1].shape[0]
# : a_train[a_train.ySkAFOzx_LaWZy==1].shape[0]
# : a_train[a_train.ySkAFOzx_eTXuS==1].shape[0]
# : a_train[a_train.ySkAFOzx_yCngx==1].shape[0]
# : a_train[a_train.dkPWxwSF_CPYVU==1].shape[0]
# : a_train[a_train.dkPWxwSF_JzIcQ==1].shape[0]
# : a_train[a_train.dkPWxwSF_QsGjO==1].shape[0]
# : a_train[a_train.dkPWxwSF_cbMrz==1].shape[0]
# : a_train[a_train.dkPWxwSF_fGvpk==1].shape[0]
# : a_train[a_train.dkPWxwSF_icswM==1].shape[0]
# : a_train[a_train.bSaLisbO_QxVfQ==1].shape[0]
# : a_train[a_train.bSaLisbO_XPkPf==1].shape[0]
# : a_train[a_train.wKcZtLNv_BSdHw==1].shape[0]
# : a_train[a_train.wKcZtLNv_JpJAL==1].shape[0]
# : a_train[a_train.mBlWbDmc_IGJGf==1].shape[0]
# : a_train[a_train.mBlWbDmc_nAWgP==1].shape[0]
# : a_train[a_train.szowPwNq_IBEsC==1].shape[0]
# : a_train[a_train.szowPwNq_hbVPO==1].shape[0]
# : a_train[a_train.ULMvnWcn_IEECo==1].shape[0]
# : a_train[a_train.ULMvnWcn_KJmKx==1].shape[0]
# : a_train[a_train.BfGjiYom_AaeZZ==1].shape[0]
# : a_train[a_train.BfGjiYom_IwRaw==1].shape[0]
# : a_train[a_train.BfGjiYom_MAkoX==1].shape[0]
# : a_train[a_train.BfGjiYom_OofXq==1].shape[0]
# : a_train[a_train.BfGjiYom_Uxyzc==1].shape[0]
# : a_train[a_train.BfGjiYom_XlVqM==1].shape[0]
# : a_train[a_train.BfGjiYom_ZOaZy==1].shape[0]
# : a_train[a_train.BfGjiYom_ZqWZh==1].shape[0]
# : a_train[a_train.BfGjiYom_hLjkt==1].shape[0]
# : a_train[a_train.BfGjiYom_jYUYQ==1].shape[0]
# : a_train[a_train.BfGjiYom_mFeaF==1].shape[0]
# : a_train[a_train.BfGjiYom_rLgDV==1].shape[0]
# : a_train[a_train.BfGjiYom_xVCqV==1].shape[0]
# : a_train[a_train.iWEFJYkR_QdGLg==1].shape[0]
# : a_train[a_train.iWEFJYkR_zrNex==1].shape[0]
# : a_train[a_train.ogHwwdzc_aDvUR==1].shape[0]
# : a_train[a_train.ogHwwdzc_rckPT==1].shape[0]
# : a_train[a_train.BCehjxAl_Pbejz==1].shape[0]
# : a_train[a_train.BCehjxAl_gGMPn==1].shape[0]
# : a_train[a_train.CHAQHqqr_EVgBS==1].shape[0]
# : a_train[a_train.CHAQHqqr_wSjgH==1].shape[0]
# : a_train[a_train.nqndbwXP_WHbWp==1].shape[0]
# : a_train[a_train.nqndbwXP_dQnUX==1].shape[0]
# : a_train[a_train.uZGqTQUP_TmEwV==1].shape[0]
# : a_train[a_train.uZGqTQUP_WMWIa==1].shape[0]
# : a_train[a_train.uZGqTQUP_nEMgq==1].shape[0]
# : a_train[a_train.phwExnuQ_PkqbM==1].shape[0]
# : a_train[a_train.phwExnuQ_RYppC==1].shape[0]
# : a_train[a_train.SzUcfjnr_EZCEl==1].shape[0]
# : a_train[a_train.SzUcfjnr_slsIB==1].shape[0]
# : a_train[a_train.PXtHzrqw_Enjzh==1].shape[0]
# : a_train[a_train.PXtHzrqw_NSTIW==1].shape[0]
# : a_train[a_train.PXtHzrqw_aBMet==1].shape[0]
# : a_train[a_train.CNkSTLvx_rDezK==1].shape[0]
# : a_train[a_train.CNkSTLvx_wxvvO==1].shape[0]
# : a_train[a_train.tHFrzjai_MkATH==1].shape[0]
# : a_train[a_train.tHFrzjai_TCxKr==1].shape[0]
# : a_train[a_train.tHFrzjai_VNvbZ==1].shape[0]
# : a_train[a_train.tHFrzjai_VmIxP==1].shape[0]
# : a_train[a_train.tHFrzjai_cMGvm==1].shape[0]
# : a_train[a_train.tHFrzjai_sCBZQ==1].shape[0]
# : a_train[a_train.tHFrzjai_teImp==1].shape[0]
# : a_train[a_train.tHFrzjai_tsilP==1].shape[0]
# : a_train[a_train.tHFrzjai_vPKPO==1].shape[0]
# : a_train[a_train.tHFrzjai_xBZqe==1].shape[0]
# : a_train[a_train.MKozKLvT_ACTli==1].shape[0]
# : a_train[a_train.MKozKLvT_fNGQN==1].shape[0]
# : a_train[a_train.pjHvJhoZ_Kkfas==1].shape[0]
# : a_train[a_train.pjHvJhoZ_ioNum==1].shape[0]
# : a_train[a_train.zkbPtFyO_OwRVU==1].shape[0]
# : a_train[a_train.zkbPtFyO_hGOlE==1].shape[0]
# : a_train[a_train.xZBEXWPR_eXQfr==1].shape[0]
# : a_train[a_train.xZBEXWPR_odZZU==1].shape[0]
# : a_train[a_train.dyGFeFAg_jWKad==1].shape[0]
# : a_train[a_train.dyGFeFAg_jubgz==1].shape[0]
# : a_train[a_train.HfOrdgBo_nsNYE==1].shape[0]
# : a_train[a_train.HfOrdgBo_vqjDd==1].shape[0]
# : a_train[a_train.pKPTBZZq_AUBhx==1].shape[0]
# : a_train[a_train.pKPTBZZq_ZdeVO==1].shape[0]
# : a_train[a_train.pKPTBZZq_hAYSL==1].shape[0]
# : a_train[a_train.bCYWWTxH_iiEDW==1].shape[0]
# : a_train[a_train.bCYWWTxH_kKdqK==1].shape[0]
# : a_train[a_train.EQKKRGkR_NBpDn==1].shape[0]
# : a_train[a_train.EQKKRGkR_mYOPT==1].shape[0]
# : a_train[a_train.ZmJZXnoA_AtKGe==1].shape[0]
# : a_train[a_train.ZmJZXnoA_gZaHx==1].shape[0]
# : a_train[a_train.YKwvJgoP_XqDYC==1].shape[0]
# : a_train[a_train.YKwvJgoP_fHiYi==1].shape[0]
# : a_train[a_train.dAaIakDk_ANUno==1].shape[0]
# : a_train[a_train.dAaIakDk_LgmAO==1].shape[0]
# : a_train[a_train.rnJOTwVD_YakVl==1].shape[0]
# : a_train[a_train.rnJOTwVD_uoglh==1].shape[0]
# : a_train[a_train.xNUUjCIL_UlAvd==1].shape[0]
# : a_train[a_train.xNUUjCIL_ypjDA==1].shape[0]
# : a_train[a_train.JMNvdasy_FzYmh==1].shape[0]
# : a_train[a_train.JMNvdasy_deAox==1].shape[0]
# : a_train[a_train.JMNvdasy_fEkHo==1].shape[0]
# : a_train[a_train.MBQcYnjc_UHHXz==1].shape[0]
# : a_train[a_train.MBQcYnjc_YHvZN==1].shape[0]
# : a_train[a_train.cCsFudxF_PfCly==1].shape[0]
# : a_train[a_train.cCsFudxF_iArDW==1].shape[0]
# : a_train[a_train.muIetHMK_BTuQn==1].shape[0]
# : a_train[a_train.muIetHMK_GMGRq==1].shape[0]
# : a_train[a_train.muIetHMK_HXYrB==1].shape[0]
# : a_train[a_train.hJrMTBVd_iqptO==1].shape[0]
# : a_train[a_train.hJrMTBVd_jmsRI==1].shape[0]
# : a_train[a_train.TJUYOoXU_IfJGv==1].shape[0]
# : a_train[a_train.TJUYOoXU_SPzFf==1].shape[0]
# : a_train[a_train.ishdUooQ_ZsSNu==1].shape[0]
# : a_train[a_train.ishdUooQ_fgUcH==1].shape[0]
# : a_train[a_train.ishdUooQ_sAtFf==1].shape[0]
# : a_train[a_train.tjrOpVkX_IlvvB==1].shape[0]
# : a_train[a_train.tjrOpVkX_tPaEK==1].shape[0]
# : a_train[a_train.cWNZCMRB_IPNiH==1].shape[0]
# : a_train[a_train.cWNZCMRB_fJrRy==1].shape[0]
# : a_train[a_train.cgJgOfCA_lVtXj==1].shape[0]
# : a_train[a_train.cgJgOfCA_yOtiS==1].shape[0]
# : a_train[a_train.ItpCDLDM_SexDN==1].shape[0]
# : a_train[a_train.ItpCDLDM_nBfiS==1].shape[0]
# : a_train[a_train.gOGWzlYC_ENzpE==1].shape[0]
# : a_train[a_train.gOGWzlYC_IOpTr==1].shape[0]
# : a_train[a_train.ptEAnCSs_BMWoB==1].shape[0]
# : a_train[a_train.ptEAnCSs_oniXa==1].shape[0]
# : a_train[a_train.HDCjCTRd_AnmcJ==1].shape[0]
# : a_train[a_train.HDCjCTRd_ttIeY==1].shape[0]
# : a_train[a_train.lOujHrCk_Ujijg==1].shape[0]
# : a_train[a_train.lOujHrCk_faBdF==1].shape[0]
# : a_train[a_train.MARfVwUE_ZxCEl==1].shape[0]
# : a_train[a_train.MARfVwUE_lfIIh==1].shape[0]
# : a_train[a_train.orfSPOJX_MzfpW==1].shape[0]
# : a_train[a_train.orfSPOJX_WuPOk==1].shape[0]
# : a_train[a_train.OKMtkqdQ_CaKpe==1].shape[0]
# : a_train[a_train.OKMtkqdQ_bGDLK==1].shape[0]
# : a_train[a_train.QBJeqwPF_DYgTc==1].shape[0]
# : a_train[a_train.QBJeqwPF_wreZR==1].shape[0]
# : a_train[a_train.qTginJts_bujmy==1].shape[0]
# : a_train[a_train.qTginJts_szIiM==1].shape[0]
# : a_train[a_train.JzhdOhzb_ljNoc==1].shape[0]
# : a_train[a_train.JzhdOhzb_tZYzi==1].shape[0]
# : a_train[a_train.THDtJuYh_GXiqH==1].shape[0]
# : a_train[a_train.THDtJuYh_jVUJV==1].shape[0]
# : a_train[a_train.QqoiIXtI_CIAdN==1].shape[0]
# : a_train[a_train.QqoiIXtI_zKnUs==1].shape[0]
# : a_train[a_train.XVwajTfe_XkLSK==1].shape[0]
# : a_train[a_train.XVwajTfe_fGhVW==1].shape[0]
# : a_train[a_train.jwEuQQve_TLIpf==1].shape[0]
# : a_train[a_train.jwEuQQve_gTwcN==1].shape[0]
# : a_train[a_train.rQAsGegu_DRvSE==1].shape[0]
# : a_train[a_train.rQAsGegu_KmfbL==1].shape[0]
# : a_train[a_train.nKoaotpH_HQYUq==1].shape[0]
# : a_train[a_train.nKoaotpH_YfHbD==1].shape[0]
# : a_train[a_train.kLkPtNnh_DfvmQ==1].shape[0]
# : a_train[a_train.kLkPtNnh_SWTnt==1].shape[0]
# : a_train[a_train.TzPdCEPV_BtRty==1].shape[0]
# : a_train[a_train.TzPdCEPV_ymHWD==1].shape[0]
# : a_train[a_train.CtHqaXhY_dzqlr==1].shape[0]
# : a_train[a_train.CtHqaXhY_rKtpo==1].shape[0]
# : a_train[a_train.CtHqaXhY_tbyeH==1].shape[0]
# : a_train[a_train.DbUNVFwv_HbuZo==1].shape[0]
# : a_train[a_train.DbUNVFwv_qFmHi==1].shape[0]
# : a_train[a_train.FmSlImli_GEhZM==1].shape[0]
# : a_train[a_train.FmSlImli_lrJCa==1].shape[0]
# : a_train[a_train.UsENDgsH_rYSEv==1].shape[0]
# : a_train[a_train.UsENDgsH_rdNWR==1].shape[0]
# : a_train[a_train.mNrEOmgq_DatRI==1].shape[0]
# : a_train[a_train.mNrEOmgq_amCbL==1].shape[0]
# : a_train[a_train.PWShFLnY_FAwZM==1].shape[0]
# : a_train[a_train.PWShFLnY_FZPxd==1].shape[0]
# : a_train[a_train.uRFXnNKV_JYIAk==1].shape[0]
# : a_train[a_train.uRFXnNKV_SduuS==1].shape[0]
# : a_train[a_train.uRFXnNKV_znnto==1].shape[0]
# : a_train[a_train.lFExzVaF_DaWhn==1].shape[0]
# : a_train[a_train.lFExzVaF_shjTF==1].shape[0]
# : a_train[a_train.CVCsOVew_MsGDR==1].shape[0]
# : a_train[a_train.CVCsOVew_vKNoE==1].shape[0]
# : a_train[a_train.tlxXCDiW_WBZrK==1].shape[0]
# : a_train[a_train.tlxXCDiW_apDeO==1].shape[0]
# : a_train[a_train.IKqsuNvV_UbHra==1].shape[0]
# : a_train[a_train.IKqsuNvV_daGYP==1].shape[0]
# : a_train[a_train.ztGMreNV_cKUPi==1].shape[0]
# : a_train[a_train.ztGMreNV_fQxZN==1].shape[0]
# : a_train[a_train.CqqwKRSn_VgUWq==1].shape[0]
# : a_train[a_train.CqqwKRSn_luOlq==1].shape[0]
# : a_train[a_train.CqqwKRSn_wYFnn==1].shape[0]
# : a_train[a_train.YUExUvhq_TlGhm==1].shape[0]
# : a_train[a_train.YUExUvhq_lsZvk==1].shape[0]
# : a_train[a_train.uVnApIlJ_hlrrk==1].shape[0]
# : a_train[a_train.uVnApIlJ_qFnRN==1].shape[0]
# : a_train[a_train.fsXLyyco_TMgjA==1].shape[0]
# : a_train[a_train.fsXLyyco_fMLWp==1].shape[0]
# : a_train[a_train.UXhTXbuS_JYRII==1].shape[0]
# : a_train[a_train.UXhTXbuS_TiyXa==1].shape[0]
# : a_train[a_train.UXhTXbuS_tXjkt==1].shape[0]
# : a_train[a_train.yaHLJxDD_PjSQE==1].shape[0]
# : a_train[a_train.yaHLJxDD_fpoGk==1].shape[0]
# : a_train[a_train.yaHLJxDD_mXeMx==1].shape[0]
# : a_train[a_train.zuMWFXax_NATrp==1].shape[0]
# : a_train[a_train.zuMWFXax_guZuT==1].shape[0]
# : a_train[a_train.zuMWFXax_xaQVo==1].shape[0]
# : a_train[a_train.qlZMvcWc_YfcLB==1].shape[0]
# : a_train[a_train.qlZMvcWc_uAbfX==1].shape[0]
# : a_train[a_train.dqRtXzav_beVRD==1].shape[0]
# : a_train[a_train.dqRtXzav_eoQfm==1].shape[0]
# : a_train[a_train.ALbGNqKm_DozQi==1].shape[0]
# : a_train[a_train.ALbGNqKm_zvDKy==1].shape[0]
# : a_train[a_train.ktBqxSwa_BErcV==1].shape[0]
# : a_train[a_train.ktBqxSwa_CcnDz==1].shape[0]
# : a_train[a_train.NqPjMmKP_Dmsgc==1].shape[0]
# : a_train[a_train.NqPjMmKP_dZLEj==1].shape[0]
# : a_train[a_train.tOWnWxYe_JpItw==1].shape[0]
# : a_train[a_train.tOWnWxYe_Tpxgz==1].shape[0]
# : a_train[a_train.RvTenIlS_ZtWvn==1].shape[0]
# : a_train[a_train.RvTenIlS_sEGZl==1].shape[0]
# : a_train[a_train.GIMIxlmv_KSJgh==1].shape[0]
# : a_train[a_train.GIMIxlmv_OQJGG==1].shape[0]
# : a_train[a_train.wKVwRQIp_CHoQY==1].shape[0]
# : a_train[a_train.wKVwRQIp_eZUdE==1].shape[0]
# : a_train[a_train.ncjMNgfp_KOglf==1].shape[0]
# : a_train[a_train.ncjMNgfp_Wszpj==1].shape[0]
# : a_train[a_train.UaXLYMMh_GvSso==1].shape[0]
# : a_train[a_train.UaXLYMMh_PVFaP==1].shape[0]
# : a_train[a_train.UaXLYMMh_QPXBo==1].shape[0]
# : a_train[a_train.UaXLYMMh_SaBuU==1].shape[0]
# : a_train[a_train.UaXLYMMh_iLMNs==1].shape[0]
# : a_train[a_train.vRIvQXtC_BaOCK==1].shape[0]
# : a_train[a_train.vRIvQXtC_EUFGq==1].shape[0]
# : a_train[a_train.vRIvQXtC_SUjRo==1].shape[0]
# : a_train[a_train.vRIvQXtC_UGNXO==1].shape[0]
# : a_train[a_train.vRIvQXtC_XsbpB==1].shape[0]
# : a_train[a_train.vRIvQXtC_lUYjh==1].shape[0]
# : a_train[a_train.bKtkhUWD_lidWB==1].shape[0]
# : a_train[a_train.bKtkhUWD_mpDne==1].shape[0]
# : a_train[a_train.RJFKdmYJ_LqSiB==1].shape[0]
# : a_train[a_train.RJFKdmYJ_yNYhF==1].shape[0]
# : a_train[a_train.gllMXToa_JJjQh==1].shape[0]
# : a_train[a_train.gllMXToa_NIhUk==1].shape[0]
# : a_train[a_train.gllMXToa_PVguv==1].shape[0]
# : a_train[a_train.HhKXJWno_Xhnzw==1].shape[0]
# : a_train[a_train.HhKXJWno_YzyAB==1].shape[0]
# : a_train[a_train.VFTkSOrq_PPQFv==1].shape[0]
# : a_train[a_train.VFTkSOrq_dgNdq==1].shape[0]
# : a_train[a_train.tAYCAXge_CVqoC==1].shape[0]
# : a_train[a_train.tAYCAXge_ahmeC==1].shape[0]
# : a_train[a_train.WAFKMNwv_EyPIN==1].shape[0]
# : a_train[a_train.WAFKMNwv_nyJgy==1].shape[0]
# : a_train[a_train.mHzqKSuN_DlKdC==1].shape[0]
# : a_train[a_train.mHzqKSuN_oUocy==1].shape[0]
# : a_train[a_train.UjuNwfjv_ACFXG==1].shape[0]
# : a_train[a_train.UjuNwfjv_BPDVj==1].shape[0]
# : a_train[a_train.UjuNwfjv_BzKTi==1].shape[0]
# : a_train[a_train.UjuNwfjv_EAPwG==1].shape[0]
# : a_train[a_train.UjuNwfjv_Fgjtq==1].shape[0]
# : a_train[a_train.UjuNwfjv_KGGBe==1].shape[0]
# : a_train[a_train.UjuNwfjv_NRTfh==1].shape[0]
# : a_train[a_train.UjuNwfjv_OYmHr==1].shape[0]
# : a_train[a_train.UjuNwfjv_Plypt==1].shape[0]
# : a_train[a_train.UjuNwfjv_ZBMyY==1].shape[0]
# : a_train[a_train.UjuNwfjv_cUIwE==1].shape[0]
# : a_train[a_train.UjuNwfjv_mxfzY==1].shape[0]
# : a_train[a_train.UjuNwfjv_qRkFm==1].shape[0]
# : a_train[a_train.UjuNwfjv_ujWYB==1].shape[0]
# : a_train[a_train.aWlBVrkK_ImUfE==1].shape[0]
# : a_train[a_train.aWlBVrkK_kfyIl==1].shape[0]
# : a_train[a_train.cDkXTaWP_TorQt==1].shape[0]
# : a_train[a_train.cDkXTaWP_cGRjt==1].shape[0]
# : a_train[a_train.hnmsRSvN_UtgfX==1].shape[0]
# : a_train[a_train.hnmsRSvN_VbSEa==1].shape[0]
# : a_train[a_train.ZzUrQSMj_eABnh==1].shape[0]
# : a_train[a_train.ZzUrQSMj_ybHKD==1].shape[0]
# : a_train[a_train.GHmAeUhZ_IHYKX==1].shape[0]
# : a_train[a_train.GHmAeUhZ_wPGlI==1].shape[0]
# : a_train[a_train.GHmAeUhZ_xqXhV==1].shape[0]
# : a_train[a_train.VBjVVDwp_CEvAs==1].shape[0]
# : a_train[a_train.VBjVVDwp_bsSvo==1].shape[0]
# : a_train[a_train.VBjVVDwp_hxaxk==1].shape[0]
# : a_train[a_train.RMbjnrlm_cTdqL==1].shape[0]
# : a_train[a_train.RMbjnrlm_tVlsB==1].shape[0]
# : a_train[a_train.kZVpcgJL_bgCry==1].shape[0]
# : a_train[a_train.kZVpcgJL_lMOhc==1].shape[0]
# : a_train[a_train.zvjiUrCR_rpmnk==1].shape[0]
# : a_train[a_train.zvjiUrCR_wjqLD==1].shape[0]
# : a_train[a_train.BIofZdtd_FDtgc==1].shape[0]
# : a_train[a_train.BIofZdtd_XXDhf==1].shape[0]
# : a_train[a_train.QZiSWCCB_AZwXA==1].shape[0]
# : a_train[a_train.QZiSWCCB_wxJis==1].shape[0]
# : a_train[a_train.sDGibZrP_JqHnW==1].shape[0]
# : a_train[a_train.sDGibZrP_ezRNB==1].shape[0]
# : a_train[a_train.CsGvKKBJ_MaXfS==1].shape[0]
# : a_train[a_train.CsGvKKBJ_jkHEU==1].shape[0]
# : a_train[a_train.OLpGAaEu_HxnJy==1].shape[0]
# : a_train[a_train.OLpGAaEu_USRak==1].shape[0]
# : a_train[a_train.OLpGAaEu_etZsD==1].shape[0]
# : a_train[a_train.LrDrWRjC_idRwx==1].shape[0]
# : a_train[a_train.LrDrWRjC_jXsPl==1].shape[0]
# : a_train[a_train.JCDeZBXq_LPtkN==1].shape[0]
# : a_train[a_train.JCDeZBXq_UyAms==1].shape[0]
# : a_train[a_train.HGPWuGlV_WKNwg==1].shape[0]
# : a_train[a_train.HGPWuGlV_vkbkA==1].shape[0]
# : a_train[a_train.GDUPaBQs_qCEuA==1].shape[0]
# : a_train[a_train.GDUPaBQs_qQxrL==1].shape[0]
# : a_train[a_train.WuwrCsIY_AITFl==1].shape[0]
# : a_train[a_train.WuwrCsIY_GAZGl==1].shape[0]
# : a_train[a_train.AlDbXTlZ_aQeIm==1].shape[0]
# : a_train[a_train.AlDbXTlZ_cecIq==1].shape[0]
# : a_train[a_train.country_A==1].shape[0]
